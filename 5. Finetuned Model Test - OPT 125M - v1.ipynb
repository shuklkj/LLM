# %% [markdown]
# # Final Project
# ## ADSP 32021 IP01 Machine Learning Operations
# ### 5: Finetuned Model Test
# #### Group 2: Maria Clarissa Fionalita, Kajal Shukla, Mia Zhang, Priya Suvvaru Venkata

# %%
# !python --version
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Python 3.10.13
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "cpu"

# %%
# from huggingface_hub import notebook_login
# # https://huggingface.co/settings/tokens

# notebook_login()

# %% [markdown]
# # Load FineTuned OPT-125M

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from optimum.bettertransformer import BetterTransformer

from pprint import pprint

# %%
# %%time

model_name = "facebook/opt-125m"
new_model_name = "model/opt_125_data_v1"

model = AutoModelForCausalLM.from_pretrained(new_model_name)
model = BetterTransformer.transform(model, keep_original_model=True) #enable CPU inference but not all models are supported

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
tokenizer.add_eos_token = True
tokenizer.add_bos_token, tokenizer.add_eos_token
# Out:
# The BetterTransformer implementation does not support padding during training, as the fused kernels do not support attention masks. Beware that passing padded batched data during training may result in unexpected outputs. Please refer to https://huggingface.co/docs/optimum/bettertransformer/overview for more details.
# CPU times: user 5.3 s, sys: 24 s, total: 29.3 s
# Wall time: 9.09 s
# (True, True)

# %%
def inference(text, model, tokenizer, max_input_tokens = 1000, max_output_tokens = 100):
    device = model.device
    # Tokenize
    input_ids = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=max_input_tokens).to(device)

    # Generate
    generated_tokens = model.generate(input_ids=input_ids.to(device), max_length=max_output_tokens, temperature = 0.4, pad_token_id=tokenizer.eos_token_id, do_sample = True)

    # Decode
    generated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    
    # Strip the prompt
    generated_text_answer = generated_text[0][len(text):]
    
    return generated_text_answer

# %%
def qa_gen(text, model, tokenizer, max_output_tokens = 100):
    # instruction = "instruction: please answer the following question\n"
    question = "question: " + str(text) + "\n"
    prompt = question + "answer:"
    print(prompt)
    print("-------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------")
    print(inference(text = prompt, model = model, tokenizer = tokenizer, max_output_tokens = max_output_tokens))
    print("-------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------")

# %%
# %%time

text = "hello?"

qa_gen(text = text, model = model, tokenizer = tokenizer, max_output_tokens = 30)
# Out:
# question: hello?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
# /home/mariafshan/miniconda3/envs/py310/lib/python3.10/site-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
#  If you're allergic to pollen, you're not allergic to the stuff you eat. But it can be a
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
# CPU times: user 26 s, sys: 160 ms, total: 26.2 s
# Wall time: 3.28 s

# %% [markdown]
# # N-Shot Learning

# %%
test_prompt = ["What types of exercise are best for people with asthma?", "How is obsessive-compulsive disorder diagnosed?", "When are you more likely to get a blood clot?", "How should you lift objects to prevent back pain?", "How can you be smart with antibiotics?"]

test_prompt[0]
# Out:
# 'What types of exercise are best for people with asthma?'

# %% [markdown]
# # Zero-Shot

# %%
# %%time

for prompt in test_prompt:
    qa_gen(text = prompt, model = model, tokenizer = tokenizer, max_output_tokens = 100)
    print()
# Out:
# question: What types of exercise are best for people with asthma?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  You are a helpful assistant that can answer medical questions. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know.
#
#     ### Context information is below:
#     A sarcoma is a rare kind of cancer. Sarcomas are different from the much more common carcinomas because they happen in a different kind
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: How is obsessive-compulsive disorder diagnosed?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  You are not a helpful assistant that can answer medical questions. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know.
#
#     ### Context information is below:
#     var s_context; s_context= s_context || {}; s_context['wb.modimp'] = 'vidfloat'; if(
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: When are you more likely to get a blood clot?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  When are you more likely to get a blood clot? This is a common problem that happens when your blood pressure gets too high. If it's not treated, you can get a serious condition called hypertension that can put you at risk for heart attack or stroke. Experts say 80% of people with high blood pressure are going to have some type of stroke. That's why there's a lot you can do to prevent
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: How should you lift objects to prevent back pain?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you're not sure you have a rheumatoid arthritis ( RA), ask your doctor. She can check your symptoms and make a treatment plan. If it's not working, you can ask your doctor to find a treatment that works for you. Most people with RA have some type of inflammation -- called multifocal leukoencephalopathy ( MF ligation). MF ligation is a serious medical condition that can
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: How can you be smart with antibiotics?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you're taking antibiotics to treat a serious bacterial infection, you shouldn't stop taking them, even if it's gone. The FDA has approved these medications to treat serious infections when there's a strong immune response to them. They include: Ibuprofen Naproxen Prescription Strength, Strength, and Strength These medications are often prescribed to treat infections caused by bacteria, viruses, yeast, fungi, and other foreign substances.
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# CPU times: user 10min 7s, sys: 2.25 s, total: 10min 9s
# Wall time: 1min 16s

# %% [markdown]
# # One Shot

# %%
# %%time

one_shot_sample = """
question: What should I do if I want to stop dialysis?\n
answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.\n
question: """

for prompt in test_prompt:
    one_shot_qa = one_shot_sample + prompt + "\n" + "answer:"
    print(one_shot_qa)
    print("-------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------")
    print(inference(text = one_shot_qa, model = model, tokenizer = tokenizer, max_output_tokens = 200))
    print("-------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------")
# Out:
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: What types of exercise are best for people with asthma?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  Exercise is best for people with asthma. Other types of exercise include: Aerobic exercise: Any rhythmic physical activity that uses large muscle groups and causes the heart and lungs to work harder than when your body is at rest. It also raises your blood pressure and can improve your circulation. Ambulatory cardio exercise: Any rhythmic physical activity that
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: How is obsessive-compulsive disorder diagnosed?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  It's hard to tell for sure from a single image. But the condition has been around since at least the 1930s. It's also called obsessive compulsive disorder because of the way you handle daily problems (such as sleep problems, mood problems, or irritability). People with obsessive compulsive disorder have trouble with everyday things, like eating, sleeping
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: When are you more likely to get a blood clot?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  When are you more likely to have a heart attack or stroke?
#
#  answer: When are you more likely to have a heart attack or stroke?
#
#  answer: When are you more likely to have a kidney or liver disease?
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: How should you lift objects to prevent back pain?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you have diabetes, you need to take insulin to control blood sugar levels. The amount can vary depending on your age, gender, and other factors. The best way is to eat a balanced diet rich in key nutrients, like: Fruit Milk and yogurt Bread, cereal, and rice Fatty, greasy items and high-fiber foods
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: How can you be smart with antibiotics?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you want to stop dialysis, what should you do?
#  answer: Here are some tips that may help you feel better: Eat a healthy diet. It's a good idea to be on the lookout for good things for your body. For example, you may find that certain foods, drinks, and medicines can make you feel better. Try to
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
# CPU times: user 12min 12s, sys: 2.74 s, total: 12min 15s
# Wall time: 1min 31s

# %% [markdown]
# # Few Shot

# %%
# %%time

few_shot_sample = """
question: What should I do if I want to stop dialysis?\n
answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.\n
question: What are some tips to stay healthy during dialysis?\n
answer: Hemodialysis patients are also at an increased risk for infections. Try these tips to stay healthy: Check your access site daily for redness, pus, and swelling. If you see any, call your doctor. Keep the bandage that covers your catheter clean and dry.\n
question:"""

for prompt in test_prompt:
    few_shot_qa = few_shot_sample + prompt + "\n" + "answer:"
    print(few_shot_qa)
    print("-------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------")
    print(inference(text = one_shot_qa, model = model, tokenizer = tokenizer, max_output_tokens = 200))
    print("-------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------")
# Out:
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: What are some tips to stay healthy during dialysis?
#
# answer: Hemodialysis patients are also at an increased risk for infections. Try these tips to stay healthy: Check your access site daily for redness, pus, and swelling. If you see any, call your doctor. Keep the bandage that covers your catheter clean and dry.
#
# question:What types of exercise are best for people with asthma?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you want to stop dialysis, do you need to make lifestyle changes or medications?
#
#  answer: Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: What are some tips to stay healthy during dialysis?
#
# answer: Hemodialysis patients are also at an increased risk for infections. Try these tips to stay healthy: Check your access site daily for redness, pus, and swelling. If you see any, call your doctor. Keep the bandage that covers your catheter clean and dry.
#
# question:How is obsessive-compulsive disorder diagnosed?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you want to stop dialysis, do you need to take medications? or do you just need to take them as directed? --
#
#
#
#  Answer: If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: What are some tips to stay healthy during dialysis?
#
# answer: Hemodialysis patients are also at an increased risk for infections. Try these tips to stay healthy: Check your access site daily for redness, pus, and swelling. If you see any, call your doctor. Keep the bandage that covers your catheter clean and dry.
#
# question:When are you more likely to get a blood clot?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  How can you be smart with antibiotics?
#
#  answer: How can you be smart with antibiotics?
#
#  answer: Medications can help you manage your blood sugar levels and prevent infections. They can also lower your blood pressure and lower your cholesterol levels. Taking antibiotics when you have symptoms or when they make you sick may make you feel less hungry. You
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: What are some tips to stay healthy during dialysis?
#
# answer: Hemodialysis patients are also at an increased risk for infections. Try these tips to stay healthy: Check your access site daily for redness, pus, and swelling. If you see any, call your doctor. Keep the bandage that covers your catheter clean and dry.
#
# question:How should you lift objects to prevent back pain?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you want to stop dialysis, what should you do?
#  answer: They're used to treat certain conditions, so it's important to understand their pros and cons. Antibiotics are sometimes used to treat bacteria and viruses, but they don't work for cancer. There are other drugs that can help your body control these conditions, too. Your
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: What should I do if I want to stop dialysis?
#
# answer: But you can choose not to have it or stop at any time. If you do, make sure to talk to your doctor about other treatments that can help you. Changes to your diet or lifestyle may improve your quality of life. If you want to stop dialysis because you feel depressed or ashamed, your doctor may urge you to speak to a counselor first. Sharing your feelings, taking antidepressants, or doing both of these things may help you make a more informed decision.
#
# question: What are some tips to stay healthy during dialysis?
#
# answer: Hemodialysis patients are also at an increased risk for infections. Try these tips to stay healthy: Check your access site daily for redness, pus, and swelling. If you see any, call your doctor. Keep the bandage that covers your catheter clean and dry.
#
# question:How can you be smart with antibiotics?
# answer:
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#  If you want to stop dialysis, what should you do?
#
#  answer: The counselor will help you understand your options and offer advice on which treatments are right for you. It also helps to know the options that are most likely to work for you and what you can do to make them work the best. These therapies are used to treat people with
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
# CPU times: user 12min 9s, sys: 2.65 s, total: 12min 11s
# Wall time: 1min 31s

# %% [markdown]
# # Retrieval Augmented Generation Prompt Engineering

# %% [markdown]
# ## Load the Vector Store Database

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA

# %%
# %%time

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cpu'}

# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to False
encode_kwargs = {'normalize_embeddings': False}

# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name = "sentence-transformers/all-MiniLM-l6-v2",     # Provide the pre-trained model's path
    model_kwargs = model_kwargs, # Pass the model configuration options
    encode_kwargs = encode_kwargs # Pass the encoding options
)
# Out:
# CPU times: user 581 ms, sys: 50.2 ms, total: 631 ms
# Wall time: 405 ms

# %%
# %%time

db = FAISS.load_local("data/RAG_data", embeddings)
# Out:
# CPU times: user 2.07 s, sys: 360 ms, total: 2.43 s
# Wall time: 2.51 s

# %% [markdown]
# ## Create the Retriever

# %% [markdown]
# https://github.com/langchain-ai/langchain/discussions/3115

# %%
# Create a retriever object from the 'db' with a search configuration where it retrieves up to 4 relevant splits/documents.
retriever = db.as_retriever(search_type = "mmr", search_kwargs={"k": 4})

# %%
# test retriever
for prompt in test_prompt:
    print(prompt)
    print(retriever.get_relevant_documents(prompt)[0].page_content)
    print()
# Out:
# What types of exercise are best for people with asthma?
# Regular exercise can help you control your asthma. It can strengthen lung muscles, make it easier to manage your weight, and boost your immune system. Instead: Try different kinds of activities that are less challenging. Avoid weather conditions that might trigger symptoms.
#
# How is obsessive-compulsive disorder diagnosed?
# People with obsessive compulsive disorder ( OCD) have recurring and distressing thoughts, fears, or images (obsessions) that they cannot control. The anxiety (nervousness) produced by these thoughts leads to an urgent need to perform certain rituals or routines (compulsions). With BDD, a person's preoccupation with the defect often leads to ritualistic behaviors, such as constantly looking in a mirror or picking at the skin. The person with BDD eventually becomes so obsessed with the defect that his or her social, work, and home functioning suffers.
#
# When are you more likely to get a blood clot?
# You might need to take a blood-thinning medicine for a few weeks before you start on one of these drugs to prevent a clot.
#
# How should you lift objects to prevent back pain?
# You can lower your chances of throwing your back out by maintaining a healthy lifestyle. You can also protect your back by not lifting heavy objects. If you can't avoid it, be sure lift the right way: Bend your knees and keep your back straight. It will keep you from pulling something or hurting your back. But if you use a heating pad, be careful.
#
# How can you be smart with antibiotics?
# Antibiotics.

# %% [markdown]
# ## Initialize the LLM Pipeline

# %% [markdown]
# ### Define the Prompt Template

# %%
from langchain.prompts import PromptTemplate

qa_template = """You are a helpful assistant that can answer medical questions. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Context information is below:

{context}

Given the context information and not prior knowledge, answer the question: {question}
Answer: """

prompt_template = PromptTemplate(
    template = qa_template,
    input_variables = ["context", "question"]
)

# %%
# test prompt

print(
    prompt_template.invoke(
        {"context": "filler context", "question": "filler question"}
    ).to_string()
)
# Out:
# You are a helpful assistant that can answer medical questions. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
# Context information is below:
#
# filler context
#
# Given the context information and not prior knowledge, answer the question: filler question
# Answer:

# %% [markdown]
# ### Load the Model into a Chain

# %%
import json
from pathlib import Path
from pprint import pprint
import ast

from langchain.llms.huggingface_pipeline import HuggingFacePipeline
from langchain.llms import HuggingFaceHub

# %%
# %%time

pipe = pipeline("text-generation",
                model = model,
                tokenizer=tokenizer,
                model_kwargs = {"temperature": 0.4, "max_length": 100, "pad_token_id": tokenizer.eos_token_id, "do_sample": True},
                max_new_tokens = 100)

llm = HuggingFacePipeline(pipeline = pipe)
# Out:
# CPU times: user 1.72 ms, sys: 137 µs, total: 1.85 ms
# Wall time: 1.57 ms

# %%
from langchain.schema import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough
# https://python.langchain.com/docs/use_cases/question_answering/

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt_template
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ## Generate Output

# %%
# %%time

for prompt in test_prompt:
    print("question:", prompt)
    result = rag_chain.invoke(prompt)
    print("-------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------")
    print()
    print(result)
    print()
    print("-------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------")
    print()
# Out:
# question: What types of exercise are best for people with asthma?
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#
# erythema asthma, the type of exercise should you do?
#
#  answer: The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of exercise should you do? The types of
#
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: How is obsessive-compulsive disorder diagnosed?
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#
# vernacular anxiety disorder?
#
#
#  answer: The person with obsessive compulsive disorder (obsessions) and person with obsessive compulsive disorder (compulsions) and person with obsessive compulsive disorder (compulsions) and person with obsessive compulsive disorder (compulsions)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: When are you more likely to get a blood clot?
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: How should you lift objects to prevent back pain?
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#
# erythema toxicum. You can lower your chances of throwing your back out by maintaining a healthy lifestyle. You can lower your chances of throwing your back out by maintaining a healthy lifestyle. You can also protect your back by not lifting heavy objects. You can also maintain your back by not lifting heavy objects. You can also lower your back by maintaining a healthy lifestyle. You can: Bend your knees and keep your back straight. You can: Bend your knees and keep your back straight. You can
#
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# question: How can you be smart with antibiotics?
# -------------------BELOW IS GENERATED BY LANGUAGE MODEL---------------------------
#
# iritis.
#
#
# “ Antibiotics,â means antibiotic. There are different types of antibiotics, including those that kill bacteria, which are used to treat infections. Others are used to treat diseases like rheumatoid arthritis, lupus, ankylosing spondylitis, ulcerative colitis, Crohn's disease, and HIV. Others are used to treat cancer, HIV, AIDS, and other infections. There are different types of
#
# -------------------END OF TEXT GENERATED BY LANGUAGE MODEL------------------------
#
# CPU times: user 36min 27s, sys: 4min 44s, total: 41min 11s
# Wall time: 5min 8s
